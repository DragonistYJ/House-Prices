# %%
import json
from typing import Optional

import pandas as pd
import pytorch_lightning as pl
import torch
from pytorch_lightning import LightningDataModule
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.loggers import TensorBoardLogger
from torch import nn
from torch.nn import functional as F
from torch.optim import AdamW
from torch.utils.data import Dataset, DataLoader, random_split
from torchmetrics import MeanSquaredError, R2Score

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
sparse_column = ["MSZoning", "Street", "Alley", "LotShape", "LandContour", "Utilities", "LotConfig", "LandSlope",
                 "Neighborhood", "Condition1", "Condition2", "BldgType", "HouseStyle", "RoofStyle", "RoofMatl",
                 "Exterior1st", "Exterior2nd", "MasVnrType", "ExterQual", "ExterCond", "Foundation", "BsmtQual",
                 "BsmtCond", "BsmtExposure", "BsmtFinType1", "BsmtFinType2", "Heating", "HeatingQC", "CentralAir",
                 "Electrical", "KitchenQual", "Functional", "FireplaceQu", "GarageType", "GarageFinish", "GarageQual",
                 "GarageCond", "PavedDrive", "PoolQC", "Fence", "MiscFeature", "SaleType", "SaleCondition"]

consistent_column = ["MSSubClass", "LotFrontage", "LotArea", "OverallQual", "OverallCond", "YearBuilt", "YearRemodAdd",
                     "MasVnrArea", "BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF", "TotalBsmtSF", "1stFlrSF", "2ndFlrSF",
                     "LowQualFinSF", "GrLivArea", "BsmtFullBath", "BsmtHalfBath", "FullBath", "HalfBath",
                     "BedroomAbvGr", "KitchenAbvGr", "TotRmsAbvGrd", "Fireplaces", "GarageYrBlt", "GarageCars",
                     "GarageArea", "WoodDeckSF", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", "ScreenPorch", "PoolArea",
                     "MiscVal", "MoSold", "YrSold"]

# %%
class MyDataset(Dataset):
    def __init__(self):
        self.csv = pd.read_csv("./data/train.csv")
        numeric = list(self.csv._get_numeric_data().columns)
        for col in numeric:
            if col == 'Id' or col == "SalePrice":
                continue
            self.csv[col] = (self.csv[col] - self.csv[col].mean()) / self.csv[col].std() if (
                    self.csv[col].std() > 0) else 1
        with open("./data/sparse_label.json", "r", encoding="utf-8") as f:
            self.sparse_label = json.loads(f.read())
        with open("./data/sparse_column.json", "r", encoding="utf-8") as f:
            self.sparse_column = json.loads(f.read())

    def __len__(self):
        return len(self.csv)

    def __getitem__(self, index):
        item = self.csv.iloc[index]
        feat = []
        for head in self.csv:
            if head == "Id" or head == "SalePrice":
                continue
            if head in self.sparse_label:
                idx = self.sparse_label[head]["label2idx"][item[head]]
                feat.append(idx)
            else:
                feat.append(item[head])
        return {"feat": torch.tensor(feat), "price": item["SalePrice"]}


def collate_function(data):
    feat = [datum["feat"] for datum in data]
    feat = torch.stack(feat).float()
    price = [datum["price"] for datum in data]
    price = torch.tensor(price).float()
    return {"feat": feat, "price": price}

# %%
class MyDataModule(LightningDataModule):
    def __init__(self):
        super().__init__()

    def setup(self, stage: Optional[str] = None) -> None:
        dataset = MyDataset()
        self.train_dataset, self.val_dataset = random_split(dataset, [1260, 200])

    def train_dataloader(self):
        return DataLoader(self.train_dataset, 1024, True, collate_fn=collate_function)

    def val_dataloader(self):
        return DataLoader(self.val_dataset, 1024, False, collate_fn=collate_function)

# %%
class LinearModel(pl.LightningModule):
    def __init__(self):
        super().__init__()
        self.lr = 1e-4
        self.conv5 = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=8, kernel_size=5, stride=1),
            nn.ReLU(),
            nn.Conv1d(in_channels=8, out_channels=16, kernel_size=5, stride=2),
            nn.ReLU()
        )
        self.conv7 = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=8, kernel_size=7, stride=1),
            nn.ReLU(),
            nn.Conv1d(in_channels=8, out_channels=16, kernel_size=7, stride=2),
            nn.ReLU()
        )
        self.conv9 = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=8, kernel_size=9, stride=1),
            nn.ReLU(),
            nn.Conv1d(in_channels=8, out_channels=16, kernel_size=9, stride=2),
            nn.ReLU()
        )
        self.fc1 = nn.Linear(1632, 1024)
        self.fc2 = nn.Linear(1024, 1024)
        self.fc3 = nn.Linear(1024, 1024)
        self.fc4 = nn.Linear(1024, 1024)
        self.fc5 = nn.Linear(1024, 140)
        self.fc6 = nn.Linear(140, 1)

        self.mse = MeanSquaredError()
        self.r2 = R2Score()

    def forward(self, feat):
        batch_size, _ = feat.size()
        x = feat.unsqueeze(dim=1)
        x5 = F.relu(self.conv5(x))
        x5 = x5.view(batch_size, -1)
        x7 = F.relu(self.conv7(x))
        x7 = x7.view(batch_size, -1)
        x9 = F.relu(self.conv9(x))
        x9 = x9.view(batch_size, -1)
        x = torch.cat((x5, x7, x9), dim=1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x)) + x
        x = F.relu(self.fc3(x)) + x
        x = F.relu(self.fc4(x)) + x
        x = F.relu(self.fc5(x))
        x = self.fc6(x)
        x = x.squeeze(dim=1)
        return x

    def training_step(self, batch, batch_idx):
        predict = self(batch["feat"])
        loss = F.mse_loss(predict.abs().log10(), batch["price"].log10())
        return {"loss": loss}

    def training_epoch_end(self, outputs):
        total_loss = 0
        for output in outputs:
            total_loss += output["loss"].item()

        self.logger.log_metrics({"train loss": total_loss}, self.current_epoch + 1)

    def validation_step(self, batch, batch_idx):
        predict = self(batch["feat"])
        self.mse(predict, batch["price"])
        self.r2(predict, batch["price"])

    def validation_epoch_end(self, outputs):
        mse = self.mse.compute()
        r2 = self.r2.compute()
        self.logger.log_metrics({"mse": mse.item(), "r2": r2.item()}, self.current_epoch + 1)
        self.mse.reset()
        self.r2.reset()

    def configure_optimizers(self):
        return AdamW(self.parameters(), lr=self.lr)

# %%
model = LinearModel()

# %%
logger = TensorBoardLogger('logs', name='cnn')
checkpoint = ModelCheckpoint(dirpath="./checkpoints/cnn", save_top_k=0)
trainer = pl.Trainer(max_epochs=400,
                     logger=logger,
                     callbacks=[checkpoint],
                     reload_dataloaders_every_n_epochs=5)
# Out:
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# E:\miniconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\trainer.py:1303: UserWarning: GPU available but not used. Set the gpus flag in your trainer `Trainer(gpus=1)` or script `--gpus=1`.
#   rank_zero_warn(

# %%
trainer.fit(model, datamodule=MyDataModule())
# Out:
#    | Name  | Type             | Params
# --------------------------------------------
# 0  | conv5 | Sequential       | 704
# 1  | conv7 | Sequential       | 976
# 2  | conv9 | Sequential       | 1.2 K
# 3  | fc1   | Linear           | 1.7 M
# 4  | fc2   | Linear           | 1.0 M
# 5  | fc3   | Linear           | 1.0 M
# 6  | fc4   | Linear           | 1.0 M
# 7  | fc5   | Linear           | 143 K
# 8  | fc6   | Linear           | 141
# 9  | mse   | MeanSquaredError | 0
# 10 | r2    | R2Score          | 0
# --------------------------------------------
# 5.0 M     Trainable params
# 0         Non-trainable params
# 5.0 M     Total params
# 19.870    Total estimated model params size (MB)
# Validation sanity check:   0%|          | 0/1 [00:00<?, ?it/s]
# E:\miniconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\data_loading.py:105: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Epoch 0:   0%|          | 0/3 [00:00<00:00, 333.33it/s]
# E:\miniconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\data_loading.py:105: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# E:\miniconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\data_loading.py:326: UserWarning: The number of training samples (2) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 0:  67%|██████▋   | 2/3 [00:02<00:00,  1.31it/s, loss=0.0276, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 3/3 [00:02<00:00,  1.57it/s, loss=0.0276, v_num=7]
# Epoch 1:  67%|██████▋   | 2/3 [00:01<00:00,  1.84it/s, loss=0.0271, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|██████████| 3/3 [00:01<00:00,  2.10it/s, loss=0.0271, v_num=7]
# Epoch 2:  67%|██████▋   | 2/3 [00:01<00:00,  1.91it/s, loss=0.0272, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|██████████| 3/3 [00:01<00:00,  2.21it/s, loss=0.0272, v_num=7]
# Epoch 3:  67%|██████▋   | 2/3 [00:01<00:00,  1.95it/s, loss=0.0269, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|██████████| 3/3 [00:01<00:00,  2.28it/s, loss=0.0269, v_num=7]
# Epoch 4:  67%|██████▋   | 2/3 [00:01<00:00,  2.06it/s, loss=0.0268, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|██████████| 3/3 [00:01<00:00,  2.39it/s, loss=0.0268, v_num=7]
# Epoch 5:  67%|██████▋   | 2/3 [00:01<00:00,  1.62it/s, loss=0.0265, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|██████████| 3/3 [00:02<00:00,  1.87it/s, loss=0.0265, v_num=7]
# Epoch 6:  67%|██████▋   | 2/3 [00:02<00:00,  1.39it/s, loss=0.0264, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|██████████| 3/3 [00:02<00:00,  1.66it/s, loss=0.0264, v_num=7]
# Epoch 7:  67%|██████▋   | 2/3 [00:01<00:00,  2.11it/s, loss=0.0262, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 7: 100%|██████████| 3/3 [00:01<00:00,  2.45it/s, loss=0.0262, v_num=7]
# Epoch 8:  67%|██████▋   | 2/3 [00:01<00:00,  2.10it/s, loss=0.0261, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|██████████| 3/3 [00:01<00:00,  2.38it/s, loss=0.0261, v_num=7]
# Epoch 9:  67%|██████▋   | 2/3 [00:01<00:00,  2.11it/s, loss=0.0259, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|██████████| 3/3 [00:01<00:00,  2.46it/s, loss=0.0259, v_num=7]
# Epoch 10:  67%|██████▋   | 2/3 [00:01<00:00,  2.07it/s, loss=0.0256, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 10: 100%|██████████| 3/3 [00:01<00:00,  2.37it/s, loss=0.0256, v_num=7]
# Epoch 11:  67%|██████▋   | 2/3 [00:01<00:00,  1.81it/s, loss=0.0254, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 11: 100%|██████████| 3/3 [00:01<00:00,  2.12it/s, loss=0.0254, v_num=7]
# Epoch 12:  67%|██████▋   | 2/3 [00:01<00:00,  1.77it/s, loss=0.0251, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 12: 100%|██████████| 3/3 [00:01<00:00,  2.05it/s, loss=0.0251, v_num=7]
# Epoch 13:  67%|██████▋   | 2/3 [00:01<00:00,  2.06it/s, loss=0.0249, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 13: 100%|██████████| 3/3 [00:01<00:00,  2.41it/s, loss=0.0249, v_num=7]
# Epoch 14:  67%|██████▋   | 2/3 [00:01<00:00,  2.16it/s, loss=0.0246, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 14: 100%|██████████| 3/3 [00:01<00:00,  2.51it/s, loss=0.0246, v_num=7]
# Epoch 15:  67%|██████▋   | 2/3 [00:01<00:00,  2.19it/s, loss=0.0245, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 15: 100%|██████████| 3/3 [00:01<00:00,  2.56it/s, loss=0.0245, v_num=7]
# Epoch 16:  67%|██████▋   | 2/3 [00:01<00:00,  1.92it/s, loss=0.0243, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 16: 100%|██████████| 3/3 [00:01<00:00,  2.24it/s, loss=0.0243, v_num=7]
# Epoch 17:  67%|██████▋   | 2/3 [00:01<00:00,  1.98it/s, loss=0.0239, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 17: 100%|██████████| 3/3 [00:01<00:00,  2.31it/
v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 41: 100%|██████████| 3/3 [00:01<00:00,  2.57it/s, loss=0.016, v_num=7]
# Epoch 42:  67%|██████▋   | 2/3 [00:01<00:00,  2.30it/s, loss=0.0158, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 42: 100%|██████████| 3/3 [00:01<00:00,  2.65it/s, loss=0.0158, v_num=7]
# Epoch 43:  67%|██████▋   | 2/3 [00:01<00:00,  1.98it/s, loss=0.0155, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 43: 100%|██████████| 3/3 [00:01<00:00,  2.26it/s, loss=0.0155, v_num=7]
# Epoch 44:  67%|██████▋   | 2/3 [00:01<00:00,  1.96it/s, loss=0.0152, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 44: 100%|██████████| 3/3 [00:01<00:00,  2.29it/s, loss=0.0152, v_num=7]
# Epoch 45:  67%|██████▋   | 2/3 [00:01<00:00,  2.16it/s, loss=0.0148, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 45: 100%|██████████| 3/3 [00:01<00:00,  2.54it/s, loss=0.0148, v_num=7]
# Epoch 46:  67%|██████▋   | 2/3 [00:01<00:00,  2.24it/s, loss=0.0145, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 46: 100%|██████████| 3/3 [00:01<00:00,  2.62it/s, loss=0.0145, v_num=7]
# Epoch 47:  67%|██████▋   | 2/3 [00:01<00:00,  2.14it/s, loss=0.0144, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 47: 100%|██████████| 3/3 [00:01<00:00,  2.48it/s, loss=0.0144, v_num=7]
# Epoch 48:  67%|██████▋   | 2/3 [00:01<00:00,  2.05it/s, loss=0.014, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 48: 100%|██████████| 3/3 [00:01<00:00,  2.34it/s, loss=0.014, v_num=7]
# Epoch 49:  67%|██████▋   | 2/3 [00:01<00:00,  1.99it/s, loss=0.0136, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 49: 100%|██████████| 3/3 [00:01<00:00,  2.28it/s, loss=0.0136, v_num=7]
# Epoch 50:  67%|██████▋   | 2/3 [00:01<00:00,  1.87it/s, loss=0.0134, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 50: 100%|██████████| 3/3 [00:01<00:00,  2.21it/s, loss=0.0134, v_num=7]
# Epoch 51:  67%|██████▋   | 2/3 [00:01<00:00,  2.12it/s, loss=0.013, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 51: 100%|██████████| 3/3 [00:01<00:00,  2.40it/s, loss=0.013, v_num=7]
# Epoch 52:  67%|██████▋   | 2/3 [00:01<00:00,  2.16it/s, loss=0.0126, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 52: 100%|██████████| 3/3 [00:01<00:00,  2.47it/s, loss=0.0126, v_num=7]
# Epoch 53:  67%|██████▋   | 2/3 [00:01<00:00,  2.16it/s, loss=0.0124, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 53: 100%|██████████| 3/3 [00:01<00:00,  2.43it/s, loss=0.0124, v_num=7]
# Epoch 54:  67%|██████▋   | 2/3 [00:01<00:00,  1.75it/s, loss=0.0122, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 54: 100%|██████████| 3/3 [00:01<00:00,  2.02it/s, loss=0.0122, v_num=7]
# Epoch 55:  67%|██████▋   | 2/3 [00:01<00:00,  1.78it/s, loss=0.012, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 55: 100%|██████████| 3/3 [00:01<00:00,  2.08it/s, loss=0.012, v_num=7]
# Epoch 56:  67%|██████▋   | 2/3 [00:01<00:00,  2.18it/s, loss=0.0118, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 56: 100%|██████████| 3/3 [00:01<00:00,  2.53it/s, loss=0.0118, v_num=7]
# Epoch 57:  67%|██████▋   | 2/3 [00:01<00:00,  2.13it/s, loss=0.0114, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 57: 100%|██████████| 3/3 [00:01<00:00,  2.48it/s, loss=0.0114, v_num=7]
# Epoch 58:  67%|██████▋   | 2/3 [00:01<00:00,  2.13it/s, loss=0.0113, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 58: 100%|██████████| 3/3 [00:01<00:00,  2.48it/s, loss=0.0113, v_num=7]
# Epoch 59:  67%|██████▋   | 2/3 [00:01<00:00,  1.99it/s, loss=0.011, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 59: 100%|██████████| 3/3 [00:01<00:00,  2.29it/s, loss=0.011, v_num=7]
# Epoch 60:  67%|██████▋   | 2/3 [00:01<00:00,  1.90it/s, loss=0.0107, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 60: 100%|██████████| 3/3 [00:01<00:00,  2.21it/s, loss=0.0107, v_num=7]
# Epoch 61:  67%|██████▋   | 2/3 [00:01<00:00,  2.09it/s, loss=0.0106, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 61: 100%|██████████| 3/3 [00:01<00:00,  2.47it/s, loss=0.0106, v_num=7]
# Epoch 62:  67%|██████▋   | 2/3 [00:01<00:00,  2.21it/s, loss=0.0103, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 62: 100%|██████████| 3/3 [00:01<00:00,  2.57it/s, loss=0.0103, v_num=7]
# Epoch 63:  67%|██████▋   | 2/3 [00:01<00:00,  2.29it/s, loss=0.00994, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 63: 100%|██████████| 3/3 [00:01<00:00,  2.66it/s, loss=0.00994, v_num=7]
# Epoch 64:  67%|██████▋   | 2/3 [00:01<00:00,  2.17it/s, loss=0
v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 88: 100%|██████████| 3/3 [00:01<00:00,  2.37it/s, loss=0.00733, v_num=7]
# Epoch 89:  67%|██████▋   | 2/3 [00:01<00:00,  2.18it/s, loss=0.00721, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 89: 100%|██████████| 3/3 [00:01<00:00,  2.52it/s, loss=0.00721, v_num=7]
# Epoch 90:  67%|██████▋   | 2/3 [00:01<00:00,  2.23it/s, loss=0.00716, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 90: 100%|██████████| 3/3 [00:01<00:00,  2.58it/s, loss=0.00716, v_num=7]
# Epoch 91:  67%|██████▋   | 2/3 [00:01<00:00,  2.17it/s, loss=0.00713, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 91: 100%|██████████| 3/3 [00:01<00:00,  2.48it/s, loss=0.00713, v_num=7]
# Epoch 92:  67%|██████▋   | 2/3 [00:01<00:00,  1.90it/s, loss=0.00712, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 92: 100%|██████████| 3/3 [00:01<00:00,  2.19it/s, loss=0.00712, v_num=7]
# Epoch 93:  67%|██████▋   | 2/3 [00:01<00:00,  1.84it/s, loss=0.00706, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 93: 100%|██████████| 3/3 [00:01<00:00,  2.10it/s, loss=0.00706, v_num=7]
# Epoch 94:  67%|██████▋   | 2/3 [00:01<00:00,  2.08it/s, loss=0.00706, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 94: 100%|██████████| 3/3 [00:01<00:00,  2.45it/s, loss=0.00706, v_num=7]
# Epoch 95:  67%|██████▋   | 2/3 [00:01<00:00,  2.14it/s, loss=0.00692, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 95: 100%|██████████| 3/3 [00:01<00:00,  2.52it/s, loss=0.00692, v_num=7]
# Epoch 96:  67%|██████▋   | 2/3 [00:01<00:00,  2.17it/s, loss=0.00688, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 96: 100%|██████████| 3/3 [00:01<00:00,  2.43it/s, loss=0.00688, v_num=7]
# Epoch 97:  67%|██████▋   | 2/3 [00:01<00:00,  1.88it/s, loss=0.00682, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 97: 100%|██████████| 3/3 [00:01<00:00,  2.18it/s, loss=0.00682, v_num=7]
# Epoch 98:  67%|██████▋   | 2/3 [00:01<00:00,  1.91it/s, loss=0.00691, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 98: 100%|██████████| 3/3 [00:01<00:00,  2.23it/s, loss=0.00691, v_num=7]
# Epoch 99:  67%|██████▋   | 2/3 [00:01<00:00,  2.18it/s, loss=0.00692, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 99: 100%|██████████| 3/3 [00:01<00:00,  2.55it/s, loss=0.00692, v_num=7]
# Epoch 100:  67%|██████▋   | 2/3 [00:01<00:00,  2.25it/s, loss=0.00692, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 100: 100%|██████████| 3/3 [00:01<00:00,  2.61it/s, loss=0.00692, v_num=7]
# Epoch 101:  67%|██████▋   | 2/3 [00:01<00:00,  2.08it/s, loss=0.00677, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 101: 100%|██████████| 3/3 [00:01<00:00,  2.45it/s, loss=0.00677, v_num=7]
# Epoch 102:  67%|██████▋   | 2/3 [00:01<00:00,  1.92it/s, loss=0.00679, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 102: 100%|██████████| 3/3 [00:01<00:00,  2.22it/s, loss=0.00679, v_num=7]
# Epoch 103:  67%|██████▋   | 2/3 [00:01<00:00,  1.91it/s, loss=0.00679, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 103: 100%|██████████| 3/3 [00:01<00:00,  2.16it/s, loss=0.00679, v_num=7]
# Epoch 104:  67%|██████▋   | 2/3 [00:01<00:00,  1.93it/s, loss=0.00669, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 104: 100%|██████████| 3/3 [00:01<00:00,  2.26it/s, loss=0.00669, v_num=7]
# Epoch 105:  67%|██████▋   | 2/3 [00:01<00:00,  2.12it/s, loss=0.00662, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 105: 100%|██████████| 3/3 [00:01<00:00,  2.47it/s, loss=0.00662, v_num=7]
# Epoch 106:  67%|██████▋   | 2/3 [00:01<00:00,  2.17it/s, loss=0.00655, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 106: 100%|██████████| 3/3 [00:01<00:00,  2.53it/s, loss=0.00655, v_num=7]
# Epoch 107:  67%|██████▋   | 2/3 [00:01<00:00,  2.08it/s, loss=0.00652, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 107: 100%|██████████| 3/3 [00:01<00:00,  2.38it/s, loss=0.00652, v_num=7]
# Epoch 108:  67%|██████▋   | 2/3 [00:01<00:00,  1.95it/s, loss=0.00644, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 108: 100%|██████████| 3/3 [00:01<00:00,  2.30it/s, loss=0.00644, v_num=7]
# Epoch 109:  67%|██████▋   | 2/3 [00:01<00:00,  1.95it/s, loss=0.00639, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 109: 100%|██████████| 3/3 [00:01<00:00,  2.28it/s, loss=0.00639, v_num=7]
# Epoch 110:  67%|██████▋   | 2/3 [00:01<00:00,  2.18it/s, loss=0.00629, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 110: 100%|██████████| 3/3 [00:01<00:00,  2.51it/s, loss=0.00629, v_num=7]
# Epoch 111:  67%|██████▋   | 2/3 [00:01<00:00,  2.16it/s, loss=0.0063, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 111: 100%|██████████| 3/3 [00:01<00:00,  2.50it/s, loss=0.0063, v_num=7]
# Epoch 112:  67%|██████▋   | 2/3 [00:01<00:00,  1.97it/s, loss=0.00622, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 112: 100%|██████████| 3/3 [00:01<00:00,  2.29it/s, loss=0.00622, v_num=7]
# Epoch 113:  67%|██████▋   | 2/3 [00:01<00:00,  1.65it/s, loss=0.00611, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 113: 100%|██████████| 3/3 [00:02<00:00,  1.92it/s, loss=0.00611, v_num=7]
# Epoch 114:  67%|██████▋   | 2/3 [00:01<00:00,  1.89it/s, loss=0.00607, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 114: 100%|██████████| 3/3 [00:01<00:00,  2.16it/
v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 174: 100%|██████████| 3/3 [00:01<00:00,  2.49it/s, loss=0.00444, v_num=7]
# Epoch 175:  67%|██████▋   | 2/3 [00:01<00:00,  2.12it/s, loss=0.00444, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 175: 100%|██████████| 3/3 [00:01<00:00,  2.46it/s, loss=0.00444, v_num=7]
# Epoch 176:  67%|██████▋   | 2/3 [00:01<00:00,  1.86it/s, loss=0.00443, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 176: 100%|██████████| 3/3 [00:01<00:00,  2.15it/s, loss=0.00443, v_num=7]
# Epoch 177:  67%|██████▋   | 2/3 [00:01<00:00,  1.85it/s, loss=0.00439, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 177: 100%|██████████| 3/3 [00:01<00:00,  2.15it/s, loss=0.00439, v_num=7]
# Epoch 178:  67%|██████▋   | 2/3 [00:01<00:00,  1.99it/s, loss=0.00437, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 178: 100%|██████████| 3/3 [00:01<00:00,  2.32it/s, loss=0.00437, v_num=7]
# Epoch 179:  67%|██████▋   | 2/3 [00:01<00:00,  2.09it/s, loss=0.0043, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 179: 100%|██████████| 3/3 [00:01<00:00,  2.43it/s, loss=0.0043, v_num=7]
# Epoch 180:  67%|██████▋   | 2/3 [00:01<00:00,  2.15it/s, loss=0.00427, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 180: 100%|██████████| 3/3 [00:01<00:00,  2.50it/s, loss=0.00427, v_num=7]
# Epoch 181:  67%|██████▋   | 2/3 [00:01<00:00,  1.86it/s, loss=0.00427, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 181: 100%|██████████| 3/3 [00:01<00:00,  2.17it/s, loss=0.00427, v_num=7]
# Epoch 182:  67%|██████▋   | 2/3 [00:01<00:00,  1.81it/s, loss=0.00424, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 182: 100%|██████████| 3/3 [00:01<00:00,  2.08it/s, loss=0.00424, v_num=7]
# Epoch 183:  67%|██████▋   | 2/3 [00:01<00:00,  1.97it/s, loss=0.0043, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 183: 100%|██████████| 3/3 [00:01<00:00,  2.30it/s, loss=0.0043, v_num=7]
# Epoch 184:  67%|██████▋   | 2/3 [00:01<00:00,  2.14it/s, loss=0.00428, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 184: 100%|██████████| 3/3 [00:01<00:00,  2.45it/s, loss=0.00428, v_num=7]
# Epoch 185:  67%|██████▋   | 2/3 [00:01<00:00,  2.08it/s, loss=0.00425, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 185: 100%|██████████| 3/3 [00:01<00:00,  2.41it/s, loss=0.00425, v_num=7]
# Epoch 186:  67%|██████▋   | 2/3 [00:01<00:00,  1.92it/s, loss=0.00425, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 186: 100%|██████████| 3/3 [00:01<00:00,  2.21it/s, loss=0.00425, v_num=7]
# Epoch 187:  67%|██████▋   | 2/3 [00:01<00:00,  1.57it/s, loss=0.0043, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 187: 100%|██████████| 3/3 [00:02<00:00,  1.79it/s, loss=0.0043, v_num=7]
# Epoch 188:  67%|██████▋   | 2/3 [00:02<00:00,  1.03it/s, loss=0.00433, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 188: 100%|██████████| 3/3 [00:03<00:00,  1.26it/s, loss=0.00433, v_num=7]
# Epoch 189:  67%|██████▋   | 2/3 [00:01<00:00,  1.89it/s, loss=0.00429, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 189: 100%|██████████| 3/3 [00:01<00:00,  2.15it/s, loss=0.00429, v_num=7]
# Epoch 190:  67%|██████▋   | 2/3 [00:01<00:00,  1.82it/s, loss=0.00439, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 190: 100%|██████████| 3/3 [00:01<00:00,  2.12it/s, loss=0.00439, v_num=7]
# Epoch 191:  67%|██████▋   | 2/3 [00:01<00:00,  1.62it/s, loss=0.00438, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 191: 100%|██████████| 3/3 [00:02<00:00,  1.85it/s, loss=0.00438, v_num=7]
# ...
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 334: 100%|██████████| 3/3 [00:01<00:00,  2.14it/s, loss=0.00343, v_num=7]
# Epoch 335:  67%|██████▋   | 2/3 [00:01<00:00,  1.63it/s, loss=0.00347, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 335: 100%|██████████| 3/3 [00:02<00:00,  1.86it/s, loss=0.00347, v_num=7]
# Epoch 336:  67%|██████▋   | 2/3 [00:01<00:00,  1.99it/s, loss=0.00338, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 336: 100%|██████████| 3/3 [00:01<00:00,  2.31it/s, loss=0.00338, v_num=7]
# Epoch 337:  67%|██████▋   | 2/3 [00:01<00:00,  2.00it/s, loss=0.00332, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch
 100%|██████████| 3/3 [00:01<00:00,  2.50it/s, loss=0.00325, v_num=7]
# Epoch 359:  67%|██████▋   | 2/3 [00:01<00:00,  2.05it/s, loss=0.00322, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 359: 100%|██████████| 3/3 [00:01<00:00,  2.37it/s, loss=0.00322, v_num=7]
# Epoch 360:  67%|██████▋   | 2/3 [00:01<00:00,  1.86it/s, loss=0.00313, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 360: 100%|██████████| 3/3 [00:01<00:00,  2.15it/s, loss=0.00313, v_num=7]
# Epoch 361:  67%|██████▋   | 2/3 [00:01<00:00,  1.65it/s, loss=0.00317, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 361: 100%|██████████| 3/3 [00:02<00:00,  1.93it/s, loss=0.00317, v_num=7]
# Epoch 362:  67%|██████▋   | 2/3 [00:01<00:00,  1.78it/s, loss=0.0031, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 362: 100%|██████████| 3/3 [00:01<00:00,  2.13it/s, loss=0.0031, v_num=7]
# Epoch 363:  67%|██████▋   | 2/3 [00:01<00:00,  2.16it/s, loss=0.00307, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 363: 100%|██████████| 3/3 [00:01<00:00,  2.50it/s, loss=0.00307, v_num=7]
# Epoch 364:  67%|██████▋   | 2/3 [00:01<00:00,  2.16it/s, loss=0.00306, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 364: 100%|██████████| 3/3 [00:01<00:00,  2.51it/s, loss=0.00306, v_num=7]
# Epoch 365:  67%|██████▋   | 2/3 [00:01<00:00,  1.94it/s, loss=0.00305, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 365: 100%|██████████| 3/3 [00:01<00:00,  2.22it/s, loss=0.00305, v_num=7]
# Epoch 366:  67%|██████▋   | 2/3 [00:01<00:00,  1.84it/s, loss=0.00306, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 366: 100%|██████████| 3/3 [00:01<00:00,  2.14it/s, loss=0.00306, v_num=7]
# Epoch 367:  67%|██████▋   | 2/3 [00:01<00:00,  1.95it/s, loss=0.00302, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 367: 100%|██████████| 3/3 [00:01<00:00,  2.30it/s, loss=0.00302, v_num=7]
# Epoch 368:  67%|██████▋   | 2/3 [00:01<00:00,  1.93it/s, loss=0.00304, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 368: 100%|██████████| 3/3 [00:01<00:00,  2.25it/s, loss=0.00304, v_num=7]
# Epoch 369:  67%|██████▋   | 2/3 [00:01<00:00,  1.75it/s, loss=0.00307, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 369: 100%|██████████| 3/3 [00:01<00:00,  2.08it/s, loss=0.00307, v_num=7]
# Epoch 370:  67%|██████▋   | 2/3 [00:01<00:00,  1.76it/s, loss=0.00305, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 370: 100%|██████████| 3/3 [00:02<00:00,  1.99it/s, loss=0.00305, v_num=7]
# Epoch 371:  67%|██████▋   | 2/3 [00:01<00:00,  1.66it/s, loss=0.00306, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 371: 100%|██████████| 3/3 [00:02<00:00,  1.90it/s, loss=0.00306, v_num=7]
# Epoch 372:  67%|██████▋   | 2/3 [00:01<00:00,  1.92it/s, loss=0.00317, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 372: 100%|██████████| 3/3 [00:01<00:00,  2.25it/s, loss=0.00317, v_num=7]
# Epoch 373:  67%|██████▋   | 2/3 [00:01<00:00,  1.90it/s, loss=0.0031, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 373: 100%|██████████| 3/3 [00:01<00:00,  2.22it/s, loss=0.0031, v_num=7]
# Epoch 374:  67%|██████▋   | 2/3 [00:01<00:00,  2.09it/s, loss=0.00308, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 374: 100%|██████████| 3/3 [00:01<00:00,  2.45it/s, loss=0.00308, v_num=7]
# Epoch 375:  67%|██████▋   | 2/3 [00:01<00:00,  1.87it/s, loss=0.00306, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 375: 100%|██████████| 3/3 [00:01<00:00,  2.16it/s, loss=0.00306, v_num=7]
# Epoch 376:  67%|██████▋   | 2/3 [00:01<00:00,  1.89it/s, loss=0.00312, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 376: 100%|██████████| 3/3 [00:01<00:00,  2.17it/s, loss=0.00312, v_num=7]
# Epoch 377:  67%|██████▋   | 2/3 [00:01<00:00,  1.76it/s, loss=0.00305, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 377: 100%|██████████| 3/3 [00:01<00:00,  2.06it/s, loss=0.00305, v_num=7]
# Epoch 378:  67%|██████▋   | 2/3 [00:01<00:00,  1.99it/s, loss=0.00305, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch
 100%|██████████| 3/3 [00:01<00:00,  2.16it/s, loss=0.00293, v_num=7]
# Epoch 396:  67%|██████▋   | 2/3 [00:01<00:00,  1.83it/s, loss=0.0029, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 396: 100%|██████████| 3/3 [00:01<00:00,  2.15it/s, loss=0.0029, v_num=7]
# Epoch 397:  67%|██████▋   | 2/3 [00:01<00:00,  2.05it/s, loss=0.00287, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 397: 100%|██████████| 3/3 [00:01<00:00,  2.41it/s, loss=0.00287, v_num=7]
# Epoch 398:  67%|██████▋   | 2/3 [00:01<00:00,  2.16it/s, loss=0.00287, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 398: 100%|██████████| 3/3 [00:01<00:00,  2.48it/s, loss=0.00287, v_num=7]
# Epoch 399:  67%|██████▋   | 2/3 [00:01<00:00,  2.19it/s, loss=0.00289, v_num=7]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 399: 100%|██████████| 3/3 [00:01<00:00,  2.52it/s, loss=0.00289, v_num=7]
# Epoch 399: 100%|██████████| 3/3 [00:01<00:00,  2.51it/s, loss=0.00289, v_num=7]

# %% [markdown]
# # 测试

# %%
class PredictSet(Dataset):
    def __init__(self):
        self.csv = pd.read_csv("./data/test.csv")
        numeric = list(self.csv._get_numeric_data().columns)
        for col in numeric:
            if col == 'Id' or col == "SalePrice":
                continue
            self.csv[col] = (self.csv[col] - self.csv[col].mean()) / self.csv[col].std() if (
                    self.csv[col].std() > 0) else 1
        with open("./data/sparse_label.json", "r", encoding="utf-8") as f:
            self.sparse_label = json.loads(f.read())
        with open("./data/sparse_column.json", "r", encoding="utf-8") as f:
            self.sparse_column = json.loads(f.read())

    def __len__(self):
        return len(self.csv)

    def __getitem__(self, index):
        item = self.csv.iloc[index]
        feat = []
        for head in self.csv:
            if head == "Id":
                continue
            if head in self.sparse_label:
                idx = self.sparse_label[head]["label2idx"][item[head]]
                feat.append(idx)
            else:
                feat.append(item[head])
        return {"feat": torch.tensor(feat), "idx": item["Id"]}


def collate_fn(data):
    feat = [datum["feat"] for datum in data]
    feat = torch.stack(feat).float()
    idx = [datum["idx"] for datum in data]
    return {"feat": feat, "id": idx}

# %%
predict_set = PredictSet()
predict_loader = DataLoader(predict_set, 256, False, collate_fn=collate_fn)

# %%
model.to(device)
# Out:
# LinearModel(
#   (conv5): Sequential(
#     (0): Conv1d(1, 8, kernel_size=(5,), stride=(1,))
#     (1): ReLU()
#     (2): Conv1d(8, 16, kernel_size=(5,), stride=(2,))
#     (3): ReLU()
#   )
#   (conv7): Sequential(
#     (0): Conv1d(1, 8, kernel_size=(7,), stride=(1,))
#     (1): ReLU()
#     (2): Conv1d(8, 16, kernel_size=(7,), stride=(2,))
#     (3): ReLU()
#   )
#   (conv9): Sequential(
#     (0): Conv1d(1, 8, kernel_size=(9,), stride=(1,))
#     (1): ReLU()
#     (2): Conv1d(8, 16, kernel_size=(9,), stride=(2,))
#     (3): ReLU()
#   )
#   (fc1): Linear(in_features=1632, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc3): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc4): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc5): Linear(in_features=1024, out_features=140, bias=True)
#   (fc6): Linear(in_features=140, out_features=1, bias=True)
#   (mse): MeanSquaredError()
#   (r2): R2Score()
# )

# %%
test_result = []
with torch.no_grad():
    for batch in predict_loader:
        predict = model(batch["feat"].to(device))
        for price, id in zip(predict, batch["id"]):
            test_result.append({"Id": id, "SalePrice": price.item()})

# %%
result_df = pd.DataFrame(test_result)

# %%
result_df.to_csv("./data/result/result24.csv")
